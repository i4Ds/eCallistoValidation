# %%
from validation import *
# Out:
# C:\Users\delbe\OneDrive\Desktop\eCallistoValidation\Scripts\radiospectra2\radiospectra\version.py:12: UserWarning: could not determine radiospectra package version; this indicates a broken installation
#   warnings.warn(

# %%
spec = CallistoSpectrogram.read("Spec_test//GREENLAND_20170906_115501_63.fit.gz")
spec2 = spec.subtract_bg("constbacksub", "elimwrongchannels")
# Out:
# 0 channels eliminated
# Eliminating sharp jumps between channels ...
# 14 channels eliminated

# %%
data = abs(spec.data.flatten())
data_bg = abs(spec2.data.flatten())

data_mean = data.mean()
data_std = np.std(data)

data_mean_bg = round(data_bg.mean(), 3)
data_std_bg = round(np.std(data_bg), 3)

print(f"Std for original Spec: {data_std}")
print(f"Mean for original Spec: {data_mean}")
print(f"SNR for original Spec: {data_mean / data_std}")

print("\n")

print(f"Std for subtracted Spec: {data_std_bg}")
print(f"Mean for subtracted Spec: {data_mean_bg}")
print(f"SNR for subtracted Spec: {data_mean_bg / data_std_bg}")

spec2.plot()
# Out:
# Std for original Spec: 18.039881650783002
# Mean for original Spec: 150.39272884283247
# SNR for original Spec: 8.336680459115142
#
#
# Std for subtracted Spec: 8.008
# Mean for subtracted Spec: 6.352
# SNR for subtracted Spec: 0.7932067932067933

# %%
spec3 = CallistoSpectrogram.read("Spec_test//AUSTRIA-Krumbach_20190906_120000_10.fit.gz")
spec4 = spec3.subtract_bg("constbacksub", "elimwrongchannels")
# Out:
# 5 channels eliminated
# Eliminating sharp jumps between channels ...
# 17 channels eliminated

# %%
data3 = spec3.data.flatten()
data_bg_3 = spec4.data.flatten()

data_mean_3 = np.mean(data3)
data_std_3 = np.std(data3)

# data_mean_bg_3 = data_bg_3.mean()
data_mean_bg_3 = np.mean(data_bg_3)
data_std_bg_3 = np.std(data_bg_3)

print(f"Std for original Spec: {data_std_3}")
print(f"Mean for original Spec: {data_mean_3}")
print(f"SNR for original Spec: {data_mean_3 / data_std_3}")

print("\n")

print(f"Std for subtracted Spec: {data_std_bg_3}")
print(f"Mean for subtracted Spec: {data_mean_bg_3}")
print(f"SNR for subtracted Spec: {data_mean_bg_3 / data_std_bg_3}")

spec4.plot()
# Out:
# Std for original Spec: 11.568567949952328
# Mean for original Spec: 105.71768422567645
# SNR for original Spec: 9.13835529886066
#
#
# Std for subtracted Spec: 1.3766351298377524
# Mean for subtracted Spec: -0.010842792881841486
# SNR for subtracted Spec: -0.007876301168574273

# %%
data = spec.data.flatten()
data_bg = spec2.data.flatten()

data_mean = data.mean()
data_std = np.std(data)

data_mean_bg = round(data_bg.mean(), 3)
data_std_bg = round(np.std(data_bg), 3)

print(f"Std for original Spec: {data_std}")
print(f"Mean for original Spec: {data_mean}")
print(f"SNR for original Spec: {data_mean / data_std}")

print("\n")

print(f"Std for subtracted Spec: {data_std_bg}")
print(f"Mean for subtracted Spec: {data_mean_bg}")
print(f"SNR for subtracted Spec: {data_mean_bg / data_std_bg}")

spec2.plot()
# Out:
# Std for original Spec: 18.039881650783002
# Mean for original Spec: 150.39272884283247
# SNR for original Spec: 8.336680459115142
#
#
# Std for subtracted Spec: 9.824
# Mean for subtracted Spec: 2.823
# SNR for subtracted Spec: 0.2873574918566775
