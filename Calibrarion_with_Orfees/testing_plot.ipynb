# %%
from Orfees_read import *
# Out:
# the Orfees methods are imported....

# %%
orfees = OrfeesSpectrogram("./orfees_files/int_orf20151104_120000_0.1_test.fts")

# %%
orfees.plot()

# %%
orfees.peek()
# Out:
# /tmp/pycharm_project_368/validation/Orfees/Orfees_read.py:183: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(dates[::int(len(dates)) // 6], rotation=50, horizontalalignment="right")

# %%
dates = orfees.convert_ms_to_date()

# %%
orfees.time_axis
# Out:
# array([43199980, 43200080, 43200180, ..., 44099760, 44099860, 44099960],
#       dtype=int32)

# %%
import datetime
print(orfees.date_obs)

date = datetime.datetime.fromtimestamp(43200080)
date
# Out:
# 2015-11-04
# datetime.datetime(1971, 5, 16, 1, 1, 20)

# %%
print(dates[::int(len(dates) // 30)] )
# Out:
# [datetime.timedelta(seconds=43199, microseconds=980000), datetime.timedelta(seconds=43349, microseconds=980000), datetime.timedelta(seconds=43499, microseconds=980000), datetime.timedelta(seconds=43649, microseconds=980000), datetime.timedelta(seconds=43799, microseconds=980000), datetime.timedelta(seconds=43949, microseconds=980000), datetime.timedelta(seconds=43200), datetime.timedelta(seconds=43350), datetime.timedelta(seconds=43500), datetime.timedelta(seconds=43650), datetime.timedelta(seconds=43800), datetime.timedelta(seconds=43950), datetime.timedelta(seconds=43200, microseconds=20000), datetime.timedelta(seconds=43350, microseconds=20000), datetime.timedelta(seconds=43500, microseconds=20000), datetime.timedelta(seconds=43650, microseconds=20000), datetime.timedelta(seconds=43800, microseconds=20000), datetime.timedelta(seconds=43950, microseconds=20000), datetime.timedelta(seconds=43200, microseconds=40000), datetime.timedelta(seconds=43350, microseconds=40000), datetime.timedelta(seconds=43500, microseconds=40000), datetime.timedelta(seconds=43650, microseconds=40000), datetime.timedelta(seconds=43800, microseconds=40000), datetime.timedelta(seconds=43950, microseconds=40000), datetime.timedelta(seconds=43200, microseconds=60000), datetime.timedelta(seconds=43350, microseconds=60000), datetime.timedelta(seconds=43500, microseconds=60000), datetime.timedelta(seconds=43650, microseconds=60000), datetime.timedelta(seconds=43800, microseconds=60000), datetime.timedelta(seconds=43950, microseconds=60000)]

# %%
spec = CallistoSpectrogram.from_url('http://soleil.i4ds.ch/solarradio/data/2002-20yy_Callisto/2015/11/04/BIR_20151104_120000_03.fit.gz')
orfees.plot_range_freq(spec)
# Out:
# /tmp/pycharm_project_368/validation/Orfees/Orfees_read.py:276: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(dates[::int(len(dates)) // 6], rotation=50, horizontalalignment="right")
